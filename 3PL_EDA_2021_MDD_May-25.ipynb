# %% [markdown]
# <a href="https://colab.research.google.com/github/javier-jaime/Route-Recommender/blob/main/3PL_EDA_2021_MDD_May-25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA and Feature Engineering

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import numpy as np

from google.colab import drive
from google.colab import files

# from sklearn.cluster import KMeans # Uncomment if required

# %%
# Mount Google Drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read dataset from excel in Google Drive to Pandas Data Frame
data = pd.read_excel('drive/MyDrive/Colab Data/Hopewell 3PL Orig Data Dec 2021_Data set_MDD.xlsx', sheet_name='RawData')
print(data.shape)
data['Lean ID'] = data['Lean ID'].astype(int)
data.set_index('Lean ID', inplace=True)
# Out:
# (25692, 29)

# %%
data.head()
# Out:
#                 Tender Date First Pick Calculated Date  \
# Lean ID
# 103473910  12/31/2019 10:35           01/04/2020 00:44
# 103513165  01/02/2020 08:28           01/04/2020 01:01
# 103612501  01/03/2020 14:38           01/04/2020 01:38
# 103593735  01/03/2020 12:04           01/04/2020 01:38
# 103593457  01/03/2020 14:23           01/04/2020 01:38
#
#           First Pick Location City Last Drop Calculated Date  \
# Lean ID
# 103473910                   BOLTON          01/13/2020 08:04
# 103513165                   BOLTON          01/09/2020 05:00
# 103612501                   BOLTON          01/09/2020 19:54
# 103593735                   BOLTON          01/07/2020 07:57
# 103593457                   BOLTON          01/09/2020 19:54
#
#                   Last Drop Location Name  \
# Lean ID
# 103473910        COSTCO LANGLEY DEPOT 076
# 103513165       COSTCO DEPOT AIRDRIE 1034
# 103612501                    DOLLARAMA LP
# 103593735  METRO - MCMAHON DIST PHARM INC
# 103593457                    DOLLARAMA LP
#
#            Last Drop Location Reference Number Last Drop Location City  \
# Lean ID
# 103473910                             10273118                 LANGLEY
# 103513165                             10273117                 AIRDRIE
# 103612501                             10272755              MONT-ROYAL
# 103593735                             10394088     POINTE-AUX-TREMBLES
# 103593457                             10272755              MONT-ROYAL
#
#           Last Drop State/Province  Total Distance (km)   Weight (kg)  ...  \
# Lean ID                                                                ...
# 103473910                       BC          4319.479296  18722.434543  ...
# 103513165                       AB          3406.981248  18129.126612  ...
# 103612501                       QC           564.879744   2822.397062  ...
# 103593735                       QC           584.191872    323.683537  ...
# 103593457                       QC           564.879744   7152.811954  ...
#
#            Last Drop Original Plan Date Start  Last Drop Appt Start Date  \
# Lean ID
# 103473910                    01/13/2020 00:00           01/13/2020 07:30
# 103513165                    01/13/2020 00:00           01/13/2020 05:00
# 103612501                    01/06/2020 00:00           01/09/2020 20:00
# 103593735                    01/06/2020 00:00           01/07/2020 08:00
# 103593457                    01/06/2020 00:00           01/09/2020 20:00
#
#           Fiscal Period - Primary Date     Load Group Shipper Load Number  \
# Lean ID
# 103473910                          1.0  ZA12-CUSTOMER            10160893
# 103513165                          1.0  ZA12-CUSTOMER            10160952
# 103612501                          1.0  ZA12-CUSTOMER            10161187
# 103593735                          1.0  ZA12-CUSTOMER            10161059
# 103593457                          1.0  ZA12-CUSTOMER            10161056
#
#            Pieces Density (pcf) First Pick Location Reference Number  \
# Lean ID
# 103473910    34.0      101.1788                                 0607
# 103513165    33.0       69.1247                                 0607
# 103612501   840.0       20.9760                                 0607
# 103593735    89.0       12.9393                                 0607
# 103593457  1830.0       14.7066                                 0607
#
#           Volume (cu ft)  PRO Number
# Lean ID
# 103473910         407.95      414488
# 103513165         578.20     4037416
# 103612501         296.64  1000930055
# 103593735          55.15  1000929883
# 103593457        1072.26  1000930030
#
# [5 rows x 28 columns]

# %%
# Drop no necessary columns
data.drop(columns=['Last Drop Location Reference Number','Total Distance (km)','Fiscal Period - Primary Date','Load Group', 'Shipper Load Number', 'First Pick Location Reference Number','First Pick Appt Start Date','Last Drop Appt Start Date','Last Drop Arrival Date','First Pick Arrival Date','Pieces','PRO Number'], inplace=True)

# %%
# Empty/NA cells
data.isnull().any()
# Out:
# Tender Date                           False
# First Pick Calculated Date            False
# First Pick Location City              False
# Last Drop Calculated Date             False
# Last Drop Location Name               False
# Last Drop Location City               False
# Last Drop State/Province              False
# Weight (kg)                           False
# Number of Shipments                   False
# Pallets                               False
# Equipment Description                 False
# Temperature Class                     False
# Transportation Mode                   False
# Last Drop Original Plan Date Start    False
# Density (pcf)                         False
# Volume (cu ft)                        False
# dtype: bool

# %%
# Drop rows with Empty/NA cells uncomment if required
# data = data.dropna(axis=0)
# print(data.shape)
# data.isnull().any()

# %%
data.dtypes
# Out:
# Tender Date                            object
# First Pick Calculated Date             object
# First Pick Location City               object
# Last Drop Calculated Date              object
# Last Drop Location Name                object
# Last Drop Location City                object
# Last Drop State/Province               object
# Weight (kg)                           float64
# Number of Shipments                   float64
# Pallets                               float64
# Equipment Description                  object
# Temperature Class                      object
# Transportation Mode                    object
# Last Drop Original Plan Date Start     object
# Density (pcf)                         float64
# Volume (cu ft)                        float64
# dtype: object

# %%
data.describe(include=[object]).transpose()
# Out:
#                                     count unique                     top  \
# Tender Date                         25692  13046        08/21/2020 12:24
# First Pick Calculated Date          25692  14219        11/19/2020 00:00
# First Pick Location City            25692      2                  BOLTON
# Last Drop Calculated Date           25692  19085        11/19/2020 00:00
# Last Drop Location Name             25692    364  WALMART LOGISTICS 6081
# Last Drop Location City             25692    194             MISSISSAUGA
# Last Drop State/Province            25692     17                      ON
# Equipment Description               25692     17               53 DRY-TL
# Temperature Class                   25692      3                     DRY
# Transportation Mode                 25692      3                     LTL
# Last Drop Original Plan Date Start  25692   3724        03/24/2020 00:00
#
#                                      freq
# Tender Date                            14
# First Pick Calculated Date             29
# First Pick Location City            25691
# Last Drop Calculated Date              25
# Last Drop Location Name               988
# Last Drop Location City              2166
# Last Drop State/Province            10450
# Equipment Description                5174
# Temperature Class                   13170
# Transportation Mode                 13284
# Last Drop Original Plan Date Start    125

# %%
data.describe().transpose().round(2)
# Out:
#                        count     mean      std  min      25%      50%  \
# Weight (kg)          25692.0  8419.58  7671.98  1.1  1445.35  6527.08
# Number of Shipments  25692.0     1.36     0.96  1.0     1.00     1.00
# Pallets              25692.0    20.15    17.50  0.0     3.83    17.00
# Density (pcf)        25692.0    19.49    11.29  0.0    15.63    19.74
# Volume (cu ft)       25692.0   985.84   865.74  0.0   188.88   855.54
#
#                           75%       max
# Weight (kg)          15062.55  82358.36
# Number of Shipments      1.00     14.00
# Pallets                 35.27    196.14
# Density (pcf)           22.58    599.03
# Volume (cu ft)        1682.02  17688.06

# %%
# Convert timestamps columns to date-time format
data.iloc[:,[0,1,3,13]] = data.iloc[:, [0,1,3,13]].apply(pd.to_datetime)

# %%
# Weight Distribution is OK
print(data['Weight (kg)'].describe())
data['Weight (kg)'].plot.hist(figsize = [20, 5], fontsize = 12)
# Out:
# count    25692.000000
# mean      8419.582023
# std       7671.982607
# min          1.102230
# 25%       1445.350637
# 50%       6527.081238
# 75%      15062.547153
# max      82358.363835
# Name: Weight (kg), dtype: float64

# %%
# Total Duration between Tender Date (PO) and Required Delivery Date (RDD) is not OK
data['Total_Duration'] = data['Last Drop Original Plan Date Start'] - data['Tender Date']
print(data['Total_Duration'].describe())
data['Total_Duration'].dt.days.hist(figsize = [20, 5])
# Out:
# count                         25692
# mean      4 days 18:10:44.588977113
# std      27 days 12:49:04.814243418
# min            -4379 days +20:14:00
# 25%                 2 days 07:51:30
# 50%                 4 days 07:18:00
# 75%                 7 days 12:11:00
# max                53 days 10:13:00
# Name: Total_Duration, dtype: object

# %%
data[data['Total_Duration']<'-4000 days']
# Out:
#                   Tender Date First Pick Calculated Date  \
# Lean ID
# 116428590 2020-10-22 11:46:00        2020-10-27 07:00:00
#
#           First Pick Location City Last Drop Calculated Date  \
# Lean ID
# 116428590                   BOLTON       2020-10-27 07:44:00
#
#           Last Drop Location Name Last Drop Location City  \
# Lean ID
# 116428590         LAKE CITY FOODS             MISSISSAUGA
#
#           Last Drop State/Province   Weight (kg)  Number of Shipments  \
# Lean ID
# 116428590                       ON  18119.501381                  1.0
#
#            Pallets Equipment Description Temperature Class  \
# Lean ID
# 116428590     16.0          53 REEFER-TL      REFRIGERATED
#
#           Transportation Mode Last Drop Original Plan Date Start  \
# Lean ID
# 116428590                  TL                2008-10-27 08:00:00
#
#            Density (pcf)  Volume (cu ft)       Total_Duration
# Lean ID
# 116428590        41.3437          966.21 -4379 days +20:14:00

# %%
# Correct minimum value
data['Last Drop Original Plan Date Start'] = data['Last Drop Original Plan Date Start'].replace(data['Last Drop Original Plan Date Start'].min(),'2020-10-27 08:00:00')
data['Total Duration'] = data['Last Drop Original Plan Date Start'] - data['Tender Date']

# %%
# Calculated Duration between First Pick and Last Drop is not OK either
data['Calculated Duration'] = data['Last Drop Calculated Date'] - data['First Pick Calculated Date']
print(data['Calculated Duration'].describe())
data['Calculated Duration'].dt.days.hist(figsize = [20, 5])
# Out:
# count                        25692
# mean     3 days 12:44:48.451658103
# std      5 days 23:15:19.049194692
# min            -363 days +18:03:00
# 25%                0 days 01:30:00
# 50%                1 days 22:00:00
# 75%                6 days 16:36:45
# max              370 days 10:00:00
# Name: Calculated Duration, dtype: object

# %%
data[data['Calculated Duration']<'-359 days']
# Out:
#                   Tender Date First Pick Calculated Date  \
# Lean ID
# 93363776  2019-05-02 14:48:00        2020-05-03 12:01:00
# 101586353 2019-11-13 12:06:00        2020-11-14 12:36:00
#
#           First Pick Location City Last Drop Calculated Date  \
# Lean ID
# 93363776                    BOLTON       2019-05-07 06:04:00
# 101586353                   BOLTON       2019-11-21 01:00:00
#
#              Last Drop Location Name Last Drop Location City  \
# Lean ID
# 93363776           SOBEYS STELLARTON              STELLARTON
# 101586353  COSTCO DEPOT AIRDRIE 1034                 AIRDRIE
#
#           Last Drop State/Province   Weight (kg)  Number of Shipments  \
# Lean ID
# 93363776                        NS   6926.736966                  1.0
# 101586353                       AB  17395.540695                  1.0
#
#            Pallets Equipment Description Temperature Class  \
# Lean ID
# 93363776     17.06         53 REEFER-LTL      REFRIGERATED
# 101586353    36.00      40 DRY CONTAINER               DRY
#
#           Transportation Mode Last Drop Original Plan Date Start  \
# Lean ID
# 93363776                  LTL                2020-10-27 08:00:00
# 101586353                  IM                2019-11-21 00:00:00
#
#            Density (pcf)  Volume (cu ft)  Total_Duration Calculated Duration  \
# Lean ID
# 93363776         19.1597          797.03 4 days 09:12:00 -363 days +18:03:00
# 101586353        21.0362         1823.08 7 days 11:54:00 -360 days +12:24:00
#
#              Total Duration
# Lean ID
# 93363776  543 days 17:12:00
# 101586353   7 days 11:54:00

# %%
# Easy Fix, change Tender Date by 1 year
# data['Last Drop Calculated Date'] = data['Last Drop Calculated Date'].replace(data['Last Drop Calculated Date'].min(),'2020-05-07 01:00:00')

# %%
# Check how many rows of data per State/Province
data['Last Drop State/Province'].value_counts().to_frame().transpose()
# Out:
#                              ON    AB    QC    BC   NB   SK   MB   NS   NL  \
# Last Drop State/Province  10450  5239  3667  2320  806  755  739  723  432
#
#                           AUK  CAN  VIC  YT  NT  13  PA  IL
# Last Drop State/Province  342  146   53   7   5   3   3   2

# %%
# Create a Dataframe from 4 Western Provinces
west_data = data[data['Last Drop State/Province'].isin(['BC', 'AB', 'SK','MB'])]

# %%
# Unique Western Cities
print(len(west_data['Last Drop Location City'].unique()))
west_data['Last Drop Location City'].value_counts().to_frame()
# Out:
# 57
#                                 Last Drop Location City
# ROCKY VIEW COUNTY                                  1786
# CALGARY                                            1627
# WINNIPEG                                            737
# EDMONTON                                            618
# LANGLEY                                             584
# AIRDRIE                                             525
# REGINA                                              525
# DELTA                                               418
# VANCOUVER                                           263
# SURREY                                              246
# SASKATOON                                           230
# BURNABY                                             215
# ACHESON                                             166
# BALZAC                                              153
# RICHMOND                                            134
# ERRINGTON                                            73
# NEW WESTMINSTER                                      58
# LETHBRIDGE                                           53
# RED DEER COUNTY                                      52
# PORT COQUITLAM                                       52
# SHERWOOD PARK                                        52
# NANAIMO                                              49
# ABBOTSFORD                                           49
# GRANDE PRAIRIE                                       48
# ST. ALBERT                                           47
# KAMLOOPS                                             46
# OKOTOKS                                              40
# KELOWNA                                              33
# WETASKIWIN                                           22
# MEDICINE HAT                                         21
# CHEMAINUS                                            19
# PRINCE GEORGE                                        17
# VICTORIA                                             16
# SMITHERS                                             15
# EDMONTON INTERNATIONAL AIRPORT                       14
# LADYSMITH                                            12
# COURTENAY                                             9
# TSUU T'INA                                            5
# PITT MEADOWS                                          4
# PENTICTON                                             2
# RED DEER                                              2
# OLDS                                                  1
# DAWSON CREEK                                          1
# CHURCHILL                                             1
# VERNON                                                1
# CHILLIWACK                                            1
# FORT ST JOHN                                          1
# DUNCAN                                                1
# EDSON                                                 1
# QUESNEL                                               1
# ST. ANDREWS                                           1
# FORT SASKATCHEWAN                                     1
# LEDUC                                                 1
# SPRUCE GROVE                                          1
# LLOYDMINSTER                                          1
# PEACE RIVER                                           1
# COLD LAKE                                             1

# %%
west_data['Last Drop Location City'].value_counts().plot.bar(figsize = [30, 5], fontsize = 10)

# %%
west_data[['Last Drop Location City', 'Last Drop State/Province', 'Total_Duration']].groupby(by=['Last Drop State/Province','Last Drop Location City']).mean()
# Out:
#                                                                     Total_Duration
# Last Drop State/Province Last Drop Location City
# AB                       ACHESON                         9 days 03:05:59.277108433
#                          AIRDRIE                         9 days 03:26:55.428571428
#                          BALZAC                          8 days 05:23:17.254901960
#                          CALGARY                         7 days 17:56:07.818070067
#                          COLD LAKE                                 7 days 11:14:00
#                          EDMONTON                        8 days 12:43:09.805825242
#                          EDMONTON INTERNATIONAL AIRPORT  8 days 19:39:25.714285714
#                          EDSON                                     7 days 11:17:00
#                          FORT SASKATCHEWAN                         7 days 11:11:00
#                          GRANDE PRAIRIE                            8 days 12:32:10
#                          LEDUC                                     7 days 11:10:00
#                          LETHBRIDGE                      8 days 13:56:19.245283018
#                          LLOYDMINSTER                              7 days 11:15:00
#                          MEDICINE HAT                    8 days 10:16:54.285714285
#                          OKOTOKS                                   8 days 13:17:27
#                          OLDS                                      7 days 11:12:00
#                          PEACE RIVER                               7 days 11:12:00
#                          RED DEER                                  7 days 11:22:00
#                          RED DEER COUNTY                 8 days 13:56:57.692307692
#                          ROCKY VIEW COUNTY               6 days 18:05:46.461366181
#                          SHERWOOD PARK                   8 days 14:00:01.153846153
#                          SPRUCE GROVE                              7 days 11:14:00
#                          ST. ALBERT                      8 days 13:09:39.574468085
#                          TSUU T'INA                                7 days 15:31:12
#                          WETASKIWIN                      8 days 12:22:40.909090909
# BC                       ABBOTSFORD                     10 days 06:28:06.122448979
#                          BURNABY                         9 days 22:40:57.488372093
#                          CHEMAINUS                                10 days 10:26:00
#                          CHILLIWACK                                8 days 10:37:00
#                          COURTENAY                                10 days 14:36:00
#                          DAWSON CREEK                              9 days 11:08:00
#                          DELTA                           9 days 12:04:38.468899521
#                          DUNCAN                                    9 days 11:05:00
#                          ERRINGTON                      10 days 16:27:43.561643835
#                          FORT ST JOHN                              9 days 11:01:00
#                          KAMLOOPS                       10 days 04:21:13.043478260
#                          KELOWNA                        10 days 03:41:03.636363636
#                          LADYSMITH                                10 days 17:12:15
#                          LANGLEY                         9 days 00:43:28.561643835
#                          NANAIMO                        11 days 01:58:15.918367347
#                          NEW WESTMINSTER                 9 days 10:00:07.241379310
#                          PENTICTON                                 8 days 09:27:00
#                          PITT MEADOWS                              9 days 17:52:15
#                          PORT COQUITLAM                 10 days 03:58:53.076923076
#                          PRINCE GEORGE                   9 days 15:49:42.352941176
#                          QUESNEL                                   8 days 10:37:00
#                          RICHMOND                        9 days 22:36:03.582089552
#                          SMITHERS                                  9 days 11:00:12
#                          SURREY                          8 days 19:03:19.512195122
#                          VANCOUVER                       9 days 17:49:24.182509505
#                          VERNON                                    8 days 10:43:00
#                          VICTORIA                                 10 days 19:12:00
# MB                       CHURCHILL                                 2 days 18:19:00
#                          ST. ANDREWS                               3 days 21:28:00
#                          WINNIPEG                        6 days 10:20:44.613297150
# SK                       REGINA                          7 days 07:32:26.971428571
#                          SASKATOON                       7 days 06:20:14.869565217

# %%
# Transportation Modes Counts
west_data['Transportation Mode'].value_counts().to_frame().transpose()
# Out:
#                       LTL    IM    TL
# Transportation Mode  6189  1874  1002

# %%
# Transportation Equipment Usage
west_data[['Transportation Mode','Temperature Class', 'Equipment Description']].groupby(by=['Transportation Mode','Temperature Class','Equipment Description']).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(IM, DRY, 40 DRY CONTAINER), (IM, DRY, 53 DRY-IM), (IM, HEAT, 53 HEATED-IM), (IM, REFRIGERATED, 53 REEFER-IM), (LTL, DRY, 53 DRY - LTL IM), (LTL, DRY, 53 DRY-LTL), (LTL, DRY, 53 REEFER - LTL IM), (LTL, HEAT, 53 HEATED - LTL IM), (LTL, HEAT, 53 HEATED-LTL), (LTL, REFRIGERATED, 53 REEFER - LTL IM), (LTL, REFRIGERATED, 53 REEFER-LTL), (TL, DRY, 53 DRY-TL), (TL, HEAT, 53 HEATED-TL), (TL, REFRIGERATED, 53 REEFER-TL)]

# %%
# Distribution of Pallets is OK
print(west_data['Pallets'].describe())
west_data['Pallets'].plot.hist(figsize = [20, 5])
# Out:
# count    9053.000000
# mean       15.355377
# std        15.363571
# min         0.010000
# 25%         1.410000
# 50%         9.010000
# 75%        29.850000
# max        53.940000
# Name: Pallets, dtype: float64

# %%
# Pallets by Transportation Mode
west_data.boxplot('Pallets','Transportation Mode', figsize = [20, 5], fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
data.plot.scatter('Volume (cu ft)','Density (pcf)', figsize = [20, 5])

# %%
# Density Distribution doesn't look right
print(west_data['Density (pcf)'].describe())
west_data['Density (pcf)'].plot.hist(figsize = [20, 5])
# Out:
# count    9065.000000
# mean       19.558507
# std        11.856598
# min         2.866200
# 25%        15.681100
# 50%        19.695800
# 75%        22.628400
# max       598.672200
# Name: Density (pcf), dtype: float64

# %%
# Why so heavy?
west_data[west_data['Density (pcf)']>500]
# Out:
#                   Tender Date First Pick Calculated Date  \
# Lean ID
# 108596856 2020-04-30 11:34:00        2020-05-01 10:40:00
#
#           First Pick Location City Last Drop Calculated Date  \
# Lean ID
# 108596856                   BOLTON       2020-05-08 10:00:00
#
#           Last Drop Location Name Last Drop Location City  \
# Lean ID
# 108596856  WALMART LOGISTICS 6063                 CALGARY
#
#           Last Drop State/Province  Weight (kg)  Number of Shipments  Pallets  \
# Lean ID
# 108596856                       AB  2128.976753                  2.0      7.4
#
#           Equipment Description Temperature Class Transportation Mode  \
# Lean ID
# 108596856         53 REEFER-LTL      REFRIGERATED                 LTL
#
#           Last Drop Original Plan Date Start  Density (pcf)  Volume (cu ft)  \
# Lean ID
# 108596856                         2020-05-08       598.6722            7.84
#
#            Total_Duration Calculated Duration  Total Duration
# Lean ID
# 108596856 7 days 12:26:00     6 days 23:20:00 7 days 12:26:00

# %%
# Correlation between Weight and Pallets is OK
west_data.plot.scatter('Weight (kg)','Pallets', figsize = [20, 5])

# %% [markdown]
# ## West LTL Data Load Consolidaton

# %%
# Reduce the dataset to LTL data only 

west_LTL_data = west_data[west_data['Transportation Mode']=='LTL']

month = 11 # November only
west_LTL_data = west_LTL_data[west_LTL_data['Last Drop Original Plan Date Start'].dt.month>=month]

# Drop unnecessary columns 
west_LTL_data = west_LTL_data.drop(columns=['First Pick Location City','Number of Shipments','Transportation Mode','Equipment Description'])

# Rename remaining columns
west_LTL_data = west_LTL_data.rename(columns={'Last Drop Location Name':'Final Destination','First Pick Calculated Date':'Plan Pick Date','Last Drop Calculated Date':'Plan Drop Date','Last Drop Original Plan Date Start':'RDD', 'Tender Date':'Order Date', 'Last Drop Location City':'Destination City','Last Drop State/Province':'Destination Province'})

# Reorder and Re-index the columns
west_LTL_data = west_LTL_data.reindex(columns=['Order Date','RDD','Total Duration','Plan Pick Date','Plan Drop Date','Calculated Duration','Final Destination','Destination City','Destination Province','Temperature Class','Pallets','Weight (kg)','Volume (cu ft)','Density (pcf)'])

west_LTL_data
# Out:
#                    Order Date                 RDD   Total Duration  \
# Lean ID
# 116377810 2020-10-21 14:42:00 2020-11-02 00:00:00 11 days 09:18:00
# 116430664 2020-10-22 12:08:00 2020-11-01 00:00:00  9 days 11:52:00
# 116490708 2020-10-23 12:13:00 2020-11-02 00:00:00  9 days 11:47:00
# 116490657 2020-10-23 12:13:00 2020-11-03 00:00:00 10 days 11:47:00
# 116409139 2020-10-22 08:58:00 2020-11-03 00:00:00 11 days 15:02:00
# ...                       ...                 ...              ...
# 119153606 2020-12-22 13:17:00 2020-12-31 00:00:00  8 days 10:43:00
# 119144785 2020-12-22 11:30:00 2020-12-23 21:00:00  1 days 09:30:00
# 119153172 2020-12-22 13:10:00 2020-12-31 00:00:00  8 days 10:50:00
# 119149395 2020-12-22 12:22:00 2020-12-30 00:00:00  7 days 11:38:00
# 119148692 2020-12-22 12:13:00 2020-12-30 00:00:00  7 days 11:47:00
#
#                Plan Pick Date      Plan Drop Date Calculated Duration  \
# Lean ID
# 116377810 2020-10-22 16:30:00 2020-11-01 21:30:00    10 days 05:00:00
# 116430664 2020-10-23 17:15:00 2020-10-31 19:53:00     8 days 02:38:00
# 116490708 2020-10-24 18:30:00 2020-11-02 14:30:00     8 days 20:00:00
# 116490657 2020-10-25 12:10:00 2020-11-03 07:00:00     8 days 18:50:00
# 116409139 2020-10-26 10:57:00 2020-11-04 09:00:00     8 days 22:03:00
# ...                       ...                 ...                 ...
# 119153606 2020-12-23 19:30:00 2021-01-05 14:00:00    12 days 18:30:00
# 119144785 2020-12-23 20:00:00 2020-12-23 21:00:00     0 days 01:00:00
# 119153172 2020-12-23 20:30:00 2021-01-02 08:00:00     9 days 11:30:00
# 119149395 2020-12-23 20:54:00 2020-12-29 05:55:00     5 days 09:01:00
# 119148692 2020-12-24 12:00:00 2020-12-30 23:59:00     6 days 11:59:00
#
#                           Final Destination   Destination City  \
# Lean ID
# 116377810             OVERWAITEA FOOD GROUP            LANGLEY
# 116430664             OVERWAITEA FOOD GROUP            LANGLEY
# 116490708           WALLACE & CAREY LIMITED    NEW WESTMINSTER
# 116490657                        Q F CASECO          ERRINGTON
# 116409139             BUY-LOW FOODS LIMITED             SURREY
# ...                                     ...                ...
# 119153606                       SOBEYS WEST  ROCKY VIEW COUNTY
# 119144785              SOBEYS WEST RSC 0050  ROCKY VIEW COUNTY
# 119153172          AMAZON.COM.CA, INC. YEG1           EDMONTON
# 119149395            FEDERATED COOP LIMITED           WINNIPEG
# 119148692  LCL REGINA DISTRIBUTION CTR D034             REGINA
#
#           Destination Province Temperature Class  Pallets   Weight (kg)  \
# Lean ID
# 116377810                   BC               DRY    15.26   5981.005883
# 116430664                   BC      REFRIGERATED    27.35  11443.242675
# 116490708                   BC               DRY     6.01   2674.339967
# 116490657                   BC      REFRIGERATED     4.91   1988.707839
# 116409139                   BC               DRY     1.06    443.454610
# ...                        ...               ...      ...           ...
# 119153606                   AB              HEAT     4.44   2250.775384
# 119144785                   AB              HEAT     8.17   3797.012909
# 119153172                   AB               DRY     2.96   1344.416122
# 119149395                   MB      REFRIGERATED    18.84   7766.985135
# 119148692                   SK              HEAT    10.09   4592.187601
#
#            Volume (cu ft)  Density (pcf)
# Lean ID
# 116377810          710.26        18.5648
# 116430664         1297.30        19.4466
# 116490708          338.88        17.3982
# 116490657          228.27        19.2069
# 116409139           48.62        20.1080
# ...                   ...            ...
# 119153606          233.03        21.2939
# 119144785          339.04        24.6902
# 119153172          113.20        26.1831
# 119149395          860.03        19.9101
# 119148692          658.05        15.3849
#
# [962 rows x 14 columns]

# %%
# Calculate Slack Time as RDD - Plan Drop Date
west_LTL_data['Slack'] = west_LTL_data['RDD'] - west_LTL_data['Plan Drop Date']
print(west_LTL_data['Slack'].describe())
west_LTL_data['Slack'].dt.days.hist(figsize = [20, 5])
# Out:
# count                            962
# mean     -2 days +19:28:13.035343036
# std        2 days 18:17:21.129261861
# min               -31 days +17:30:00
# 25%                -2 days +17:46:30
# 50%                -1 days +13:34:00
# 75%                -1 days +17:33:45
# max                  5 days 12:00:00
# Name: Slack, dtype: object

# %%
# Show minimum value
west_LTL_data[west_LTL_data['Slack']==west_LTL_data['Slack'].min()]
# Out:
#                    Order Date        RDD  Total Duration      Plan Pick Date  \
# Lean ID
# 117521476 2020-11-16 11:36:00 2020-11-25 8 days 12:24:00 2020-11-17 13:35:00
#
#                Plan Drop Date Calculated Duration  \
# Lean ID
# 117521476 2020-12-25 06:30:00    37 days 16:55:00
#
#                         Final Destination Destination City  \
# Lean ID
# 117521476  COSTCO WHOLESALE 258(EDMONTON)         EDMONTON
#
#           Destination Province Temperature Class  Pallets  Weight (kg)  \
# Lean ID
# 117521476                   AB              HEAT     0.36   152.561268
#
#            Volume (cu ft)  Density (pcf)              Slack
# Lean ID
# 117521476           15.85        21.2202 -31 days +17:30:00

# %%
load_consolidation = west_LTL_data[['Destination Province','Destination City','Final Destination','Temperature Class', 'RDD','Slack','Pallets','Weight (kg)','Volume (cu ft)']].groupby(by=['Destination Province','Destination City','Final Destination','Temperature Class','RDD','Slack']).sum()
load_consolidation
# Out:
#                                                                                                              Pallets  \
# Destination Province Destination City Final Destination      Temperature Class RDD        Slack
# AB                   ACHESON          OVERWAITEA FOOD GROUP  DRY               2020-02-20 -2 days +07:35:00     5.50
#                                                                                2020-04-22 0 days 06:40:00       1.48
#                                                                                2020-05-15 -5 days +07:30:00    17.11
#                                                                                2020-05-18 -5 days +05:24:00     3.56
#                                                                                2020-05-20 0 days 07:00:00      12.21
# ...                                                                                                              ...
# SK                   SASKATOON        FEDERATED COOP LIMITED REFRIGERATED      2020-10-15 1 days 17:30:00       0.80
#                                                                                2020-10-19 -1 days +17:30:00     3.75
#                                                                                2020-12-03 -1 days +17:30:00    19.95
#                                                                                2020-12-10 -5 days +17:30:00     8.53
#                                                                                2020-12-24 1 days 17:30:00      19.19
#
#                                                                                                              Weight (kg)  \
# Destination Province Destination City Final Destination      Temperature Class RDD        Slack
# AB                   ACHESON          OVERWAITEA FOOD GROUP  DRY               2020-02-20 -2 days +07:35:00   988.459486
#                                                                                2020-04-22 0 days 06:40:00     688.199461
#                                                                                2020-05-15 -5 days +07:30:00  3207.424435
#                                                                                2020-05-18 -5 days +05:24:00  1337.458015
#                                                                                2020-05-20 0 days 07:00:00    4197.770866
# ...                                                                                                                  ...
# SK                   SASKATOON        FEDERATED COOP LIMITED REFRIGERATED      2020-10-15 1 days 17:30:00     167.529817
#                                                                                2020-10-19 -1 days +17:30:00  1356.059839
#                                                                                2020-12-03 -1 days +17:30:00  9073.104451
#                                                                                2020-12-10 -5 days +17:30:00  2743.272404
#                                                                                2020-12-24 1 days 17:30:00    7886.688170
#
#                                                                                                              Volume (cu ft)
# Destination Province Destination City Final Destination      Temperature Class RDD        Slack
# AB                   ACHESON          OVERWAITEA FOOD GROUP  DRY               2020-02-20 -2 days +07:35:00          587.35
#                                                                                2020-04-22 0 days 06:40:00             52.27
#                                                                                2020-05-15 -5 days +07:30:00          876.52
#                                                                                2020-05-18 -5 days +05:24:00          181.07
#                                                                                2020-05-20 0 days 07:00:00            751.10
# ...                                                                                                                     ...
# SK                   SASKATOON        FEDERATED COOP LIMITED REFRIGERATED      2020-10-15 1 days 17:30:00             67.13
#                                                                                2020-10-19 -1 days +17:30:00          275.45
#                                                                                2020-12-03 -1 days +17:30:00         1004.38
#                                                                                2020-12-10 -5 days +17:30:00          400.89
#                                                                                2020-12-24 1 days 17:30:00            891.64
#
# [6093 rows x 3 columns]

# %%
# Save the clean datasets to an Excel Spreadsheet
west_LTL_data.to_excel('3PL_MDD_Clean_West_LTL.xlsx', sheet_name='3PL')
load_consolidation.to_excel('3PL_West_LTL_Load_Consolidation.xlsx', sheet_name='Consolidation')
# !cp 3PL_MDD_Clean_West_LTL_Data.xlsx "/content/drive/My Drive/Colab Data/"
# !cp 3PL_West_LTL_Load_Consolidation.xlsx "/content/drive/My Drive/Colab Data/"

# %% [markdown]
# ## Geolocation Data

# %%
# Create a new Dataframe for Unique Cities
cities = west_LTL_data[['Destination City','Destination Province']].groupby(['Destination City','Destination Province']).count().reset_index()
